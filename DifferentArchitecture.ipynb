# %%
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/

# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/

# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK XLV XLF XLE XLY --output_dir outputs/architectures_5/
# Out:
# {'final_portfolio_value': 12460.568344685842, 'test_differential_sharpe': 0.07158465011925232, 'args': {'model_type': 'lstm', 'tickers': ['XLK', 'XLV', 'XLF', 'XLE', 'XLY'], 'start': '2015-01-01', 'end': '2024-01-01', 'window_size': 60, 'initial_cash': 10000, 'transaction_cost': 0.001, 'dsr_eta': 0.003968253968253968, 'action_low': -5.0, 'action_high': 5.0, 'n_envs': 10, 'n_steps': 512, 'batch_size': 1024, 'n_epochs': 300, 'gamma': 0.99, 'gae_lambda': 0.95, 'clip_range': 0.2, 'learning_rate': 0.0003, 'ent_coef': 0.0, 'hidden_size': 64, 'attention_dim': 128, 'n_heads': 4, 'total_timesteps': 200000, 'verbose': False, 'steps_per_log': 1000, 'output_dir': 'outputs/architectures_5/'}}
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# ...

# %%
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK --output_dir outputs/architectures_1/

# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLK --output_dir outputs/architectures_1/

# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK --output_dir outputs/architectures_1/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLK --output_dir outputs/architectures_1/
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# {'Technology': 'XLK'}
# Data sanity check:
# Prices mean: 45.35844
# Returns mean: 0.0007324414630651162
# Returns std: 0.014790822342565336
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# ...
