# %%
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures

# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type attention --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures

# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type linear --tickers XLB XLC XLE XLF XLI XLK XLP XLRE XLU XLV XLY --output_dir outputs/architectures
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# {'Technology': 'XLK', 'Healthcare': 'XLV', 'Financials': 'XLF', 'Energy': 'XLE', 'Industrials': 'XLI', 'Consumer Discretionary': 'XLY', 'Consumer Staples': 'XLP', 'Utilities': 'XLU', 'Materials': 'XLB', 'Real Estate': 'XLRE', 'Communication': 'XLC'}
# Data sanity check:
# Prices mean: 52.966602
# Returns mean: 0.0003755617380162964
# Returns std: 0.015291943778717234
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# ...

# %%
1
# Out:
# 1
