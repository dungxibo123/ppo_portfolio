# %%
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.2 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.2 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.2 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.2 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.2 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# {'Technology': 'XLK', 'Healthcare': 'XLV', 'Financials': 'XLF', 'Energy': 'XLE', 'Consumer Discretionary': 'XLY'}
# Data sanity check:
# Prices mean: 48.813942
# Returns mean: 0.00041870244806647245
# Returns std: 0.014663588465174893
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# ...

# %%
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.5 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.5 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.5 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.5 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.5 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# {'Technology': 'XLK', 'Healthcare': 'XLV', 'Financials': 'XLF', 'Energy': 'XLE', 'Consumer Discretionary': 'XLY'}
# Data sanity check:
# Prices mean: 48.813942
# Returns mean: 0.0004187024567766136
# Returns std: 0.014663592038132006
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# ...

# %%
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.1 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.1 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.1 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.1 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
# !python main.py --total_timesteps 500000 --n_envs 10 --test_split 0.1 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/splits/
