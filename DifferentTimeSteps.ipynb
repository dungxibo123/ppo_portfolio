# %%
# !python main.py --total_timesteps 10000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 10000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 10000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 10000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 10000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/


# !python main.py --total_timesteps 50000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 50000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 50000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 50000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 50000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/


# !python main.py --total_timesteps 100000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 100000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 100000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 100000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 100000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/

# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 200000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/


# !python main.py --total_timesteps 500000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 500000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 500000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 500000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 500000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/

# !python main.py --total_timesteps 2000000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 2000000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 2000000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 2000000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
# !python main.py --total_timesteps 2000000 --n_envs 10 --n_epochs 300 --model_type lstm --tickers XLK XLV XLF XLE XLY --output_dir outputs/timesteps/
